# %%
# !pip install pymongo
# !pip install pandas
import pymongo
import pandas as pd
MONGO_URI = 'mongodb+srv://sem:deka@cluster0.olmaj.mongodb.net/?retryWrites=true&w=majority'
# MONGO_URI = 'mongodb+srv://<username>:<password>@cluster0.olmaj.mongodb.net/?retryWrites=true&w=majority'
MONGO_DATABASE = 'product_data_test'

# %%
client = pymongo.MongoClient(MONGO_URI)
db = client[MONGO_DATABASE]
col = db['links']
doc = col.find({})

df =  pd.DataFrame(list(doc))

# ah = df[df['url'].str.match(r'.*ah\.nl') == True]
# deka = df[df['url'].str.match(r'.*dekamarkt\.nl') == True]
# vomar = df[df['url'].str.match(r'.*vomar\.nl') == True]
# jumbo = df[df['url'].str.match(r'.*jumbo\.com') == True]

#compression_opts = dict(method='zip', archive_name='supermarkt.csv')  
# df.to_csv('supermarkt.zip', index=False, compression=compression_opts)
df.head()
# Out:
#                         _id  \
# 0  62a9aab3fdbad10fd5b22de3
# 1  62a9aab3fdbad10fd5b22e02
# 2  62a9aab3fdbad10fd5b22e1f
# 3  62a9aab3fdbad10fd5b22e41
# 4  62a9aab3fdbad10fd5b22e65
#
#                                                  url                    tijd  \
# 0  https://www.jumbo.com//producten/jumbo-ultimat... 2022-07-17 17:09:50.701
# 1  https://www.jumbo.com//producten/jumbo-mais-so... 2022-06-15 11:47:31.338
# 2  https://www.jumbo.com//producten/dole-bananen-... 2022-07-17 17:09:50.885
# 3  https://www.jumbo.com//producten/jumbo-reuze-g... 2022-06-15 11:47:31.398
# 4  https://www.jumbo.com//producten/jumbo-houtsko... 2022-06-15 11:47:31.431
#
#   winkel
# 0     jb
# 1     jb
# 2     jb
# 3     jb
# 4     jb

# %%
df.describe()
# Out:
# C:\Users\SemKj\AppData\Local\Temp\ipykernel_12128\3627053830.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#                              _id  \
# count                      40025
# unique                     40025
# top     62a9aab3fdbad10fd5b22de3
# freq                           1
# first                        NaN
# last                         NaN
#
#                                                       url  \
# count                                               40025
# unique                                              40025
# top     https://www.jumbo.com//producten/jumbo-ultimat...
# freq                                                    1
# first                                                 NaN
# last                                                  NaN
#
#                               tijd winkel
# count                        40025  40025
# unique                       40025      4
# top     2022-07-17 17:09:50.701000     ah
# freq                             1  20681
# first   2022-06-15 11:47:31.338000    NaN
# last    2022-07-18 15:58:31.820000    NaN

# %%
deka
# Out:
#                             _id  \
# 0      61d160b85ceee7f471a0cc01
# 1      61d160bf5ceee7f471a0dd43
# 5      61d160cd5ceee7f471a1019f
# 6      61d160ce5ceee7f471a1040a
# 8      61d160e55ceee7f471a13c92
# ...                         ...
# 60586  61f6237b38acf3d68ee822af
# 60587  61f6238738acf3d68ee83d67
# 60588  61f6239938acf3d68ee862f1
# 60589  61f623c938acf3d68ee8d0b7
# 60590  61f623e738acf3d68ee9156e
#
#                                                      url    sku  \
# 0      https://www.dekamarkt.nl/boodschappen/maaltijd...  71065
# 1      https://www.dekamarkt.nl/boodschappen/maaltijd...  69945
# 5      https://www.dekamarkt.nl/boodschappen/maaltijd...  59943
# 6      https://www.dekamarkt.nl/boodschappen/maaltijd...  59945
# 8      https://www.dekamarkt.nl/boodschappen/zuivel-k...   1336
# ...                                                  ...    ...
# 60586  https://www.dekamarkt.nl/boodschappen/non-food...  76221
# 60587  https://www.dekamarkt.nl/boodschappen/non-food...  55818
# 60588  https://www.dekamarkt.nl/boodschappen/brood-be...    740
# 60589  https://www.dekamarkt.nl/boodschappen/maaltijd...  76250
# 60590  https://www.dekamarkt.nl/boodschappen/dranken-...  26766
#
#                                                     naam    inhoud prijs  \
# 0                         1 de Beste Maaltijdsalade zalm     450 g  4.69
# 1      1 de Beste Groene salade italiaanse mix met re...     240 g  2.99
# 5                     1 de Beste Maaltijdsalade garnalen     450 g  4.69
# 6              1 de Beste Maaltijdsalade kip sweet chili     450 g  3.99
# 8                               Campina Vlaflip framboos   1 liter  1.81
# ...                                                  ...       ...   ...
# 60586                          Atlijd handig Kaasschaaf   Per stuk  1.00
# 60587                          Brabantia Koekenpan 20 cm  Per stuk  6.99
# 60588         Het Zuiden Bloemen honing helder vloeibaar     450 g  1.95
# 60589                    Los Taqueros Soft taco kit kip      805 g  7.99
# 60590                           Lipton Ice tea sparkling    330 ml  0.80
#
#                                             omschrijving  \
# 0      Maaltijdsalade met gekookte pasta, dille-mieri...
# 1      Salade met kaas, gedroogde tomaat-crouton-pitt...
# 5      Maaltijdsalade met gekookte noedels, gekookte ...
# 6      Maaltijdsalade met gekookte noedels, gegaarde ...
# 8      Vlaflip: 45% halfvolle frisse frambozenvla, 46...
# ...                                                  ...
# 60586
# 60587
# 60588                            bloemenhoning vloeibaar
# 60589  Tarwe tortilla - Vulling op basis van tomaten ...
# 60590  Verfrissende drank met thee-extract, gezoet me...
#
#                                           categorie                    tijd  \
# 0       [Maaltijden salades tapas, Maaltijdsalades] 2022-01-30 02:00:40.895
# 1       [Maaltijden salades tapas, Maaltijdsalades] 2022-01-30 02:00:47.569
# 5       [Maaltijden salades tapas, Maaltijdsalades] 2022-01-30 02:01:01.792
# 6       [Maaltijden salades tapas, Maaltijdsalades] 2022-01-30 02:01:03.384
# 8                                [Zuivel kaas, Vla] 2022-01-30 02:01:24.481
# ...                                             ...                     ...
# 60586                          [Non food, Non food] 2022-01-30 06:34:51.208
# 60587                          [Non food, Non food] 2022-01-30 06:35:03.408
# 60588                [Brood beleg koek, Broodbeleg] 2022-01-30 06:35:21.512
# 60589  [Maaltijden salades tapas, Verse maaltijden] 2022-01-30 06:36:09.204
# 60590           [Dranken sap koffie thee, Limonade] 2022-01-30 06:36:39.191
#
#       kenmerken winkel aanbieding
# 0           NaN    NaN        NaN
# 1           NaN    NaN        NaN
# 5           NaN    NaN        NaN
# 6           NaN    NaN        NaN
# 8           NaN    NaN        NaN
# ...         ...    ...        ...
# 60586       NaN    NaN        NaN
# 60587       NaN    NaN        NaN
# 60588       NaN    NaN        NaN
# 60589       NaN    NaN        NaN
# 60590       NaN    NaN        NaN
#
# [12071 rows x 12 columns]
