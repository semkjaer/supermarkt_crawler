# %%
import pymongo
import pandas as pd
MONGO_URI = 'mongodb+srv://sem:deka@cluster0.olmaj.mongodb.net/product_data?retryWrites=true&w=majority'
MONGO_DATABASE = 'product_data'

# %%
client = pymongo.MongoClient(MONGO_URI)
db = client[MONGO_DATABASE]
col = db['products']
doc = col.find({})

df =  pd.DataFrame(list(doc))
ah = df[df['url'].str.match(r'.*ah\.nl') == True]
deka = df[df['url'].str.match(r'.*dekamarkt\.nl') == True]
vomar = df[df['url'].str.match(r'.*vomar\.nl') == True]
jumbo = df[df['url'].str.match(r'.*jumbo\.com') == True]
df.columns
# Out:
# Index(['_id', 'url', 'naam', 'omschrijving', 'inhoud', 'kenmerken', 'prijs',
#        'aanbieding'],
#       dtype='object')

# %%
for x in ah.iloc[:1].values:
    for y, z in zip(x, ah.iloc[:1]):
        print(z,':',y)
# list(ah['kenmerken'])
# Out:
# _id : 612b4d4cfcb5ea407c2dd6ca
# url : https://www.ah.nl/producten/product/wi398448/the-pie-factory-hartige-taart-runderstoof-ui
# naam : The Pie Factory Hartige taart runderstoof-ui
# omschrijving : ['Hartige Taart Pie Runderstoof met Ui']
# inhoud : ['250 Gram']
# kenmerken : []
# prijs : 2.99
# aanbieding : False

# %%
for x in deka.iloc[:1].values:
    for y, z in zip(x, ah.iloc[:1]):
        print(z,':',y)
# list(deka.omschrijving.unique())
# Out:
# _id : 612b4e04fcb5ea407c2e8e65
# url : https://www.dekamarkt.nl/boodschappen/aardappelen-groente-fruit/sla-verse-kruiden/1-de-beste-rucola-125-g/43400
# naam : 1 de Beste Rucola
# omschrijving : Rucola
# inhoud : 125 g
# kenmerken : nan
# prijs : 1.69
# aanbieding : False

# %%
len(ah['naam'].unique())
# Out:
# 3204

# %%
len(ah['naam'])
# Out:
# 3318

# %%
ah['naam'].value_counts()
# Out:
# Zwitsal Billendoek sensitive                        4
# Lucovitaal Magnesium 400 mg citraat                 3
# AH Stokbrood kruidenboter                           3
# Roter Vitamine C 1000 mg bruistabletten             3
# Roter Vitamine C 70 mg kauwtabletten citroen        3
#                                                    ..
# Ambre Solaire Dry protect mist spf 30               1
# Gillette Hydra scheergel fusion - gevoelige huid    1
# Care Shampoo iedere dag peach                       1
# Sanex Men active control deodorant spray            1
# AH Chocolate & macademia nut cookie                 1
# Name: naam, Length: 3204, dtype: int64

# %%
deka
# Out:
#                            _id  \
# 10    612b4e04fcb5ea407c2e8e65
# 11    612b4e05fcb5ea407c2e8f9c
# 12    612b4e06fcb5ea407c2e907a
# 13    612b4e08fcb5ea407c2e91a1
# 14    612b4e09fcb5ea407c2e936e
# ...                        ...
# 9928  612bae01fcb5ea407c9676db
# 9929  612bae03fcb5ea407c967850
# 9930  612bae04fcb5ea407c96790d
# 9931  612bae05fcb5ea407c967a02
# 9932  612bae07fcb5ea407c967bae
#
#                                                     url  \
# 10    https://www.dekamarkt.nl/boodschappen/aardappe...
# 11    https://www.dekamarkt.nl/boodschappen/aardappe...
# 12    https://www.dekamarkt.nl/boodschappen/aardappe...
# 13    https://www.dekamarkt.nl/boodschappen/aardappe...
# 14    https://www.dekamarkt.nl/boodschappen/aardappe...
# ...                                                 ...
# 9928  https://www.dekamarkt.nl/boodschappen/dranken-...
# 9929  https://www.dekamarkt.nl/boodschappen/voorraad...
# 9930  https://www.dekamarkt.nl/boodschappen/voorraad...
# 9931  https://www.dekamarkt.nl/boodschappen/huishoud...
# 9932  https://www.dekamarkt.nl/boodschappen/snacks-s...
#
#                                                    naam  \
# 10                                   1 de Beste Rucola
# 11                                  1 de Beste Oregano
# 12                                           Gember los
# 13                 1 de Beste Jonge bladsla met rucola
# 14                                1 de Beste Basilicum
# ...                                                 ...
# 9928                       GiG Hard seltzer lime rhythm
# 9929  Davitamon Vitamine D smelttabletten vanaf 50 jaar
# 9930                                     Smaakt Linzen
# 9931                Robijn Droogtrommeldoekjes intense
# 9932                Dextro Druivensuiker citroen 3 pack
#
#                                            omschrijving     inhoud kenmerken  \
# 10                                               Rucola      125 g       NaN
# 11                                              Oregano       20 g       NaN
# 12                                                            1 kg       NaN
# 13         Jonge bladsla in verschillende verhoudingen.       80 g       NaN
# 14                                            Basilicum       20 g       NaN
# ...                                                 ...        ...       ...
# 9928  Sprankelend Seltzerwater met natuurlijke limoe...     330 ml       NaN
# 9929                                                     130 stuks       NaN
# 9930                                             Linzen     360 ml       NaN
# 9931                                                      20 stuks       NaN
# 9932  14 Energieleverende dextrosetabletten met citr...      141 g       NaN
#
#       prijs aanbieding
# 10     1.69      False
# 11     1.19      False
# 12     5.98      False
# 13     1.49      False
# 14     1.19      False
# ...     ...        ...
# 9928   1.49      False
# 9929  15.49      False
# 9930   1.38      False
# 9931   3.32      False
# 9932   1.75      False
#
# [9880 rows x 8 columns]

# %%
ah
# Out:
#                             _id  \
# 0      612b4d4cfcb5ea407c2dd6ca
# 1      612b4d4dfcb5ea407c2dd7b3
# 2      612b4d4efcb5ea407c2dd88c
# 3      612b4d4ffcb5ea407c2dd986
# 4      612b4d52fcb5ea407c2ddca5
# ...                         ...
# 21208  612c9cfcfcb5ea407cb802bf
# 21209  612c9cfdfcb5ea407cb80318
# 21212  612c9cfefcb5ea407cb805d8
# 21216  612c9d02fcb5ea407cb80a9a
# 21218  612c9d03fcb5ea407cb80bbb
#
#                                                      url  \
# 0      https://www.ah.nl/producten/product/wi398448/t...
# 1      https://www.ah.nl/producten/product/wi442180/a...
# 2      https://www.ah.nl/producten/product/wi389578/a...
# 3      https://www.ah.nl/producten/product/wi497931/a...
# 4      https://www.ah.nl/producten/product/wi429307/p...
# ...                                                  ...
# 21208  https://www.ah.nl/producten/product/wi199402/a...
# 21209  https://www.ah.nl/producten/product/wi476421/a...
# 21212  https://www.ah.nl/producten/product/wi473738/a...
# 21216  https://www.ah.nl/producten/product/wi230748/a...
# 21218  https://www.ah.nl/producten/product/wi230783/a...
#
#                                                naam  \
# 0      The Pie Factory Hartige taart runderstoof-ui
# 1                      AH Groente quiche provencaal
# 2                  AH Mini quiche tomaat mozzarella
# 3                          AH Quiche paprika salami
# 4                           Picard Quiches lorraine
# ...                                             ...
# 21208                                    AH Romeo's
# 21209                         AH Pecan caramel koek
# 21212                                 AH Eierkoeken
# 21216           AH American cookie triple chocolate
# 21218           AH Chocolate & macademia nut cookie
#
#                                             omschrijving      inhoud  \
# 0                 [Hartige Taart Pie Runderstoof met Ui]  [250 Gram]
# 1      [Quiche met 26% tarwe-bloemkoolbodem, 10% Maas...  [300 Gram]
# 2      [Quiche met tomaat, 10% Maasdammerkaas en 3,5%...  [150 Gram]
# 3      [Quiche met 9,5% salami, paprika en 5,7% Maasd...  [300 Gram]
# 4                                  [2 quiches lorraines]  [360 Gram]
# ...                                                  ...         ...
# 21208            [Roomboterkoeken  met amandelschaafsel]  [175 Gram]
# 21209  [Roomboterkoeken met 31% karamelvulling en 6,4...  [300 Gram]
# 21212                                       [Eierkoeken]  [360 Gram]
# 21216  [Koekje van cacaodeeg met pure en witte chocol...  [60 Stuks]
# 21218                       [Cookie W Choc Mac UTZ (mb)]  [60 Stuks]
#
#            kenmerken prijs aanbieding
# 0                 []  2.99      False
# 1      [Vegetarisch]  4.19      False
# 2      [Vegetarisch]  1.95      False
# 3                 []  3.59      False
# 4      [Groene Punt]  3.60      False
# ...              ...   ...        ...
# 21208  [Vegetarisch]  2.69      False
# 21209  [Vegetarisch]  2.24       True
# 21212  [Vegetarisch]  0.98      False
# 21216             []  1.35      False
# 21218             []  1.35      False
#
# [3318 rows x 8 columns]

# %%
vomar
# Out:
#                             _id  \
# 12292  612bc54cfcb5ea407cb86d56
# 12293  612bc54dfcb5ea407cb86dcc
# 12294  612bc54efcb5ea407cb86f34
# 12295  612bc54ffcb5ea407cb8706e
# 12296  612bc551fcb5ea407cb87147
# ...                         ...
# 24769  612cb08efcb5ea407cde7d17
# 24780  612cb09afcb5ea407cde9661
# 25581  612cb4aafcb5ea407ce7c37a
# 26477  612cb93bfcb5ea407cf7425c
# 26479  612cb93dfcb5ea407cf74760
#
#                                                      url  \
# 12292  https://www.vomar.nl/producten/baby-kind/baby-...
# 12293  https://www.vomar.nl/producten/voorraadkast/zo...
# 12294  https://www.vomar.nl/producten/voorraadkast/tu...
# 12295  https://www.vomar.nl/producten/voorraadkast/so...
# 12296  https://www.vomar.nl/producten/voorraadkast/pa...
# ...                                                  ...
# 24769  https://www.vomar.nl/producten/vers/vlees/been...
# 24780  https://www.vomar.nl/producten/vers/vlees/been...
# 25581  https://www.vomar.nl/producten/vers/fruit/bio-...
# 26477  https://www.vomar.nl/producten/voorraadkast/bi...
# 26479  https://www.vomar.nl/producten/voorraadkast/bi...
#
#                                                     naam  \
# 12292  Sore Junior Mais Fingers Appel Kaneel 12+ Maan...
# 12293                 Van Gilse Fijne Kaneelsuiker 200 g
# 12294                      Bio+ Notenreep Kokos 3 x 35 g
# 12295              Hak Rode Kool met Stukjes Appel 180 g
# 12296                  Thai Temple Noodles Cup Beef 60 g
# ...                                                  ...
# 24769               Vomar Beenham Kaas en Spek ca. 770 g
# 24780             Vomar Beenham Honing-Mosterd ca. 770 g
# 25581                           Bio+ Biologische Bananen
# 26477         Weight Care Mijn Moment Melkchocolade 20 g
# 26479  Weight Care Tussendoortje Krokante Reep Pure C...
#
#                                             omschrijving  \
# 12292                   Junior Maisfingers Appel Kaneel.
# 12293                                 Fijne kaneelsuiker
# 12294           Biologische notenreep met dadel en kokos
# 12295                        Rode kool MET STUKJES APPEL
# 12296                          Instant noedels rundsmaak
# ...                                                  ...
# 24769  Varkensvleesbereiding met kaas en katenspek, m...
# 24780  Varkensvleesproduct met honing-mosterdtopping ...
# 25581                                Biologische bananen
# 26477                      Granenreep met melkchocolade.
# 26479  Krokante reep omhuld met een fijn laagje pure ...
#
#                                                   inhoud kenmerken  prijs  \
# 12292                   Junior Maisfingers Appel Kaneel.       NaN  1. 79
# 12293                                 Fijne kaneelsuiker       NaN  0. 99
# 12294           Biologische notenreep met dadel en kokos       NaN  2. 49
# 12295                        Rode kool MET STUKJES APPEL       NaN  0. 99
# 12296                          Instant noedels rundsmaak       NaN  0. 69
# ...                                                  ...       ...    ...
# 24769  Varkensvleesbereiding met kaas en katenspek, m...       NaN  8. 45
# 24780  Varkensvleesproduct met honing-mosterdtopping ...       NaN  8. 45
# 25581                                Biologische bananen       NaN  1. 69
# 26477                      Granenreep met melkchocolade.       NaN  0. 89
# 26479  Krokante reep omhuld met een fijn laagje pure ...       NaN  2. 35
#
#       aanbieding
# 12292        NaN
# 12293        NaN
# 12294        NaN
# 12295        NaN
# 12296        NaN
# ...          ...
# 24769        NaN
# 24780        NaN
# 25581        NaN
# 26477        NaN
# 26479        NaN
#
# [6993 rows x 8 columns]

# %%
jumbo
# Out:
#                             _id  \
# 19261  612c93c2fcb5ea407cad0db5
# 19262  612c93c4fcb5ea407cad1067
# 19263  612c93c5fcb5ea407cad111c
# 19264  612c93c6fcb5ea407cad1339
# 19265  612c93c7fcb5ea407cad1465
# ...                         ...
# 26988  612cbbd3fcb5ea407cff7864
# 26989  612cbbd4fcb5ea407cff7c9c
# 26990  612cbbd5fcb5ea407cff816a
# 26991  612cbbd6fcb5ea407cff84af
# 26992  612cbbd9fcb5ea407cff8d73
#
#                                                      url  \
# 19261  https://www.jumbo.com//producten/jumbo-komkomm...
# 19262  https://www.jumbo.com//producten/jumbo-runderg...
# 19263  https://www.jumbo.com//producten/tomaten-500g-...
# 19264  https://www.jumbo.com//producten/jumbo-paprika...
# 19265  https://www.jumbo.com//producten/jumbo-paprika...
# ...                                                  ...
# 26988  https://www.jumbo.com//producten/heinz-tomaten...
# 26989  https://www.jumbo.com//producten/jumbo-kip-sia...
# 26990  https://www.jumbo.com//producten/jumbo-raw-lem...
# 26991  https://www.jumbo.com//producten/kesbeke-amste...
# 26992  https://www.jumbo.com//producten/jumbo-cola-ze...
#
#                                                     naam omschrijving  \
# 19261                                    Jumbo Komkommer          NaN
# 19262                            Jumbo Rundergehakt 500g          NaN
# 19263                                       Tomaten 500g          NaN
# 19264                         Jumbo Paprika en Courgette          NaN
# 19265                                 Jumbo Paprika Rood          NaN
# ...                                                  ...          ...
# 26988  Heinz Tomaten Ketchup 50% minder suikers & zou...          NaN
# 26989                              Jumbo Kip Siam Pakket          NaN
# 26990                           Jumbo Raw Lemonade 400ml          NaN
# 26991  Kesbeke Amsterdamse Augurken en Uitjes Zoetzuu...          NaN
# 26992                Jumbo Cola Zero Sugar 4 x 6 x 330ml          NaN
#
#            inhoud kenmerken prijs aanbieding
# 19261        None       NaN  0,55        NaN
# 19262       500 g       NaN  3,69        NaN
# 19263       500 g       NaN  0,99        NaN
# 19264       250 g       NaN  1,44        NaN
# 19265        None       NaN  0,89        NaN
# ...           ...       ...   ...        ...
# 26988      400 ml       NaN  2,27        NaN
# 26989       400 g       NaN  1,99        NaN
# 26990      400 ml       NaN  1,69        NaN
# 26991      675 gr       NaN  2,15        NaN
# 26992  6 x 330 ml       NaN  5,96        NaN
#
# [6802 rows x 8 columns]
