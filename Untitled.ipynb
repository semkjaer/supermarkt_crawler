# %%
import pymongo
import pandas as pd
MONGO_URI = 'mongodb+srv://sem:deka@cluster0.olmaj.mongodb.net/product_data?retryWrites=true&w=majority'
MONGO_DATABASE = 'product_data'

# %%
client = pymongo.MongoClient(MONGO_URI)
db = client[MONGO_DATABASE]
col = db['products']
doc = col.find({})

df =  pd.DataFrame(list(doc))
ah = df[df['url'].str.match(r'.*ah\.nl') == True]
deka = df[df['url'].str.match(r'.*dekamarkt\.nl') == True]
vomar = df[df['url'].str.match(r'.*vomar\.nl') == True]
jumbo = df[df['url'].str.match(r'.*jumbo\.com') == True]
compression_opts = dict(method='zip', archive_name='supermarkt.csv')  
df.to_csv('supermarkt.zip', index=False, compression=compression_opts)
# Out:
# C:\Users\SemKj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)

# %%
ah
# Out:
#                             _id  \
# 2      61d160c45ceee7f471a0ebd5
# 3      61d160b85ceee7f471a0cd89
# 9      61d160e75ceee7f471a142bd
# 11     61d160f45ceee7f471a1614c
# 13     61d161035ceee7f471a1859d
# ...                         ...
# 37480  61d1be155ceee7f47196cfe1
# 37481  61d1be195ceee7f47196dc0a
# 37482  61d1be345ceee7f471972680
# 37483  61d1be365ceee7f471972c55
# 37484  61d1be565ceee7f471978b62
#
#                                                      url       sku  \
# 2      https://www.ah.nl/producten/product/wi511214/a...  wi511214
# 3      https://www.ah.nl/producten/product/wi506220/b...  wi506220
# 9      https://www.ah.nl/producten/product/wi466547/b...  wi466547
# 11     https://www.ah.nl/producten/product/wi484736/z...  wi484736
# 13     https://www.ah.nl/producten/product/wi506223/b...  wi506223
# ...                                                  ...       ...
# 37480  https://www.ah.nl/producten/product/wi440851/a...  wi440851
# ...

# %%
for x in deka.iloc[:1].values:
    for y, z in zip(x, ah.iloc[:1]):
        print(z,':',y)
# list(deka.omschrijving.unique())
# Out:
# _id : 61d160b85ceee7f471a0cc01
# url : https://www.dekamarkt.nl/boodschappen/maaltijden-salades-tapas/maaltijdsalades/1-de-beste-maaltijdsalade-zalm-450-g/71065
# sku : 71065
# naam : 1 de Beste Maaltijdsalade zalm
# inhoud : 450 g
# prijs : 4.69
# omschrijving : Maaltijdsalade met gekookte pasta, dille-mieriksworteldressing, gerookte zalm en kappertjes
# categorie : ['Maaltijden salades tapas', 'Maaltijdsalades']
# tijd : 2022-01-30 02:00:40.895000
# kenmerken : nan
# winkel : nan
# aanbieding : nan

# %%
len(ah['naam'].unique())
# Out:
# 18232

# %%
len(ah['naam'])
# Out:
# 19414

# %%
ah[ah['url'] == 'https://www.ah.nl/producten/product/wi455430/ah-nederlandse-trostomaten']
# Out:
#                             _id  \
# 23742  61cf04f25ceee7f471dbb07d
#
#                                                      url  \
# 23742  https://www.ah.nl/producten/product/wi455430/a...
#
#                          tijd winkel
# 23742 2022-06-13 11:12:10.262     ah

# %%
deka
# Out:
#                             _id  \
# 0      61d160b85ceee7f471a0cc01
# 1      61d160bf5ceee7f471a0dd43
# 5      61d160cd5ceee7f471a1019f
# 6      61d160ce5ceee7f471a1040a
# 8      61d160e55ceee7f471a13c92
# ...                         ...
# 60586  61f6237b38acf3d68ee822af
# 60587  61f6238738acf3d68ee83d67
# 60588  61f6239938acf3d68ee862f1
# 60589  61f623c938acf3d68ee8d0b7
# 60590  61f623e738acf3d68ee9156e
#
#                                                      url    sku  \
# 0      https://www.dekamarkt.nl/boodschappen/maaltijd...  71065
# 1      https://www.dekamarkt.nl/boodschappen/maaltijd...  69945
# 5      https://www.dekamarkt.nl/boodschappen/maaltijd...  59943
# 6      https://www.dekamarkt.nl/boodschappen/maaltijd...  59945
# 8      https://www.dekamarkt.nl/boodschappen/zuivel-k...   1336
# ...                                                  ...    ...
# 60586  https://www.dekamarkt.nl/boodschappen/non-food...  76221
# ...

# %%
ah.loc[ah['aanbieding'].isin([False, True]) == False]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
ah
# Out:
#                             _id  \
# 2      61d160c45ceee7f471a0ebd5
# 3      61d160b85ceee7f471a0cd89
# 9      61d160e75ceee7f471a142bd
# 11     61d160f45ceee7f471a1614c
# 13     61d161035ceee7f471a1859d
# ...                         ...
# 37480  61d1be155ceee7f47196cfe1
# 37481  61d1be195ceee7f47196dc0a
# 37482  61d1be345ceee7f471972680
# 37483  61d1be365ceee7f471972c55
# 37484  61d1be565ceee7f471978b62
#
#                                                      url       sku  \
# 2      https://www.ah.nl/producten/product/wi511214/a...  wi511214
# 3      https://www.ah.nl/producten/product/wi506220/b...  wi506220
# 9      https://www.ah.nl/producten/product/wi466547/b...  wi466547
# 11     https://www.ah.nl/producten/product/wi484736/z...  wi484736
# 13     https://www.ah.nl/producten/product/wi506223/b...  wi506223
# ...                                                  ...       ...
# 37480  https://www.ah.nl/producten/product/wi440851/a...  wi440851
# ...

# %%
deka_categories = dict()
for breadcrumb in deka['categorie'].dropna():
    for i, category in enumerate(breadcrumb):
        if len(breadcrumb) > i+1:
            if not breadcrumb[i] in deka_categories:
                deka_categories[breadcrumb[i]] = [breadcrumb[i+1]]
            elif breadcrumb[i+1] not in deka_categories[breadcrumb[i]] and breadcrumb[i+1] not in deka_categories[breadcrumb[i]]:
                deka_categories[breadcrumb[i]].append(breadcrumb[i+1])
            
deka_categories
# Out:
# {'Maaltijden salades tapas': ['Maaltijdsalades',
#   'Houdbare soepen',
#   'Verse maaltijden',
#   'Houdbare maaltijden',
#   'Salades',
#   'Tapas'],
#  'Zuivel kaas': ['Vla',
#   'Toetjes',
#   'Kaas stuk',
#   'Yoghurt kwark pap',
#   'Kaas gesneden',
#   'Slagroom kookroom',
#   'Boter margarine',
#   'Eieren',
#   'Overige kazen',
#   'Lactosevrije zuivel',
#   'Melk karnemelk',
#   'Zuiveldranken'],
#  'Diepvries': ['Diepvries groente',
#   'Diepvries snacks',
#   'Diepvries pizza s maaltijden',
#   'IJs',
#   'Diepvries vis',
#   'Diepvries aardappelproducten',
#   'Diepvries dierenvoeding',
#   'Diepvries vlees',
#   'Diepvries fruit deeg',
#   'Diepvries brood gebak'],
#  'Dranken sap koffie thee': ['Bier',
#   'Koffie cacao',
#   'Slijterij',
#   'Frisdranken',
#   'Limonade',
#   'Vruchtensappen',
#   'Wijn',
#   'Aperitieven mixen',
#   'Thee',
#   'Mineraal bronwater',
#   'Koffiemelk'],
#  'Kind drogisterij': ['Babyvoeding vanaf 6 maanden',
#   'Bad douche zeep',
# ...

# %%
ah_categories = dict()
for breadcrumb in ah['categorie'].dropna():
    for i, category in enumerate(breadcrumb[:2]):
        if len(breadcrumb[:2]) > i+1:
            if not breadcrumb[i] in ah_categories:
                ah_categories[breadcrumb[i]] = [{breadcrumb[i+1]: [['deka'], ['vomar']]}]
            elif breadcrumb[i+1] not in ah_categories[breadcrumb[i]] and {breadcrumb[i+1]: [['deka'], ['vomar']]} not in ah_categories[breadcrumb[i]]:
                ah_categories[breadcrumb[i]].append({breadcrumb[i+1]: [['deka'], ['vomar']]})

#for cat in ah_categories.copy():
#    if cat in ah_categories:
#        for i, x in enumerate(ah_categories[cat]):
#            if x in ah_categories:
#                ah_categories[cat][i] = ah_categories[cat][i], ah_categories.pop(x)
ah_categories
# Out:
# {'Koken, tafelen, vrije tijd': [{'Wonen, slapen': [['deka'], ['vomar']]},
#   {'Hobby, vrije tijd': [['deka'], ['vomar']]},
#   {'Koken': [['deka'], ['vomar']]},
#   {'Feestje, gelegenheid': [['deka'], ['vomar']]},
#   {'Versiering & decoratie': [['deka'], ['vomar']]},
#   {'Tafelen': [['deka'], ['vomar']]},
#   {'Tabak': [['deka'], ['vomar']]},
#   {'Kantoorartikelen': [['deka'], ['vomar']]},
#   {'Elektronica': [['deka'], ['vomar']]},
#   {'Boeken, tijdschriften': [['deka'], ['vomar']]},
#   {'Bloemen, plantverzorging': [['deka'], ['vomar']]},
#   {'Kleding, schoenonderhoud': [['deka'], ['vomar']]}],
#  'Wijn en bubbels': [{'Mousserende wijn': [['deka'], ['vomar']]},
#   {'Wijnaccessoires': [['deka'], ['vomar']]},
#   {'Rosé': [['deka'], ['vomar']]},
#   {'Rode wijn': [['deka'], ['vomar']]},
#   {'Witte wijn': [['deka'], ['vomar']]},
#   {'Wijngeschenk': [['deka'], ['vomar']]},
#   {'Port, sherry': [['deka'], ['vomar']]},
#   {'Wijntaps': [['deka'], ['vomar']]},
# ...

# %%
vm_categories = dict()
for breadcrumb in vomar['categorie'].dropna():
    for i, category in enumerate(breadcrumb):
        if len(breadcrumb) > i+1:
            if not breadcrumb[i] in vm_categories:
                vm_categories[breadcrumb[i]] = [breadcrumb[i+1]]
            elif breadcrumb[i+1] not in vm_categories[breadcrumb[i]] and breadcrumb[i+1] not in vm_categories[breadcrumb[i]]:
                vm_categories[breadcrumb[i]].append(breadcrumb[i+1])
            
            
vm_categories
# Out:
# {'Baby & Kind': ['Baby- en Kindervoeding'],
#  'Voorraadkast': ['Soepen, conserven, sauzen & smaakmakers',
#   'Pasta, rijst & wereldmarkt',
#   'Bakproducten',
#   'Chocolade & Snoep',
#   'Chips, Koek, Snacks & Nootjes',
#   'Ontbijt',
#   'Zoetstoffen',
#   'Tussendoortjes',
#   'Biologisch & Reform',
#   'Broodbeleg'],
#  'Vers': ['Zuivel, Boter & Eieren',
#   'Vleeswaren & Salades',
#   'Vlees',
#   'Verse Vis',
#   'Verse Sappen',
#   'Verse Tapas',
#   'Verse Noten',
#   'Verse Maaltijden & Maaltijdsalades',
#   'Verse Kruiden',
#   'Verse Crackers & Beschuit',
#   'Vegetarisch',
#   'Ontbijt',
#   'Kaas',
#   'Grill',
#   'Kip & Kalkoen',
#   'Groente',
#   'Fruit',
#   'Brood',
#   'Aardappelen',
#   'Banket'],
#  'Koken, Tafelen & non food': ['Tuin',
#   'Koken & Wonen',
#   'Kaarsen',
#   'Kleding & Schoenen',
#   'Haardhout & Barbecue',
#   'Kantoorartikelen',
#   'Feestartikelen'],
#  'Huishouden': ['Zakdoekjes & Tissues',
#   'Wasmiddelen & Wasverzachter',
# ...

# %%
ah
# Out:
#                             _id  \
# 0      61cdffb25ceee7f47177e9f1
# 1      61cdffb25ceee7f47177eb63
# 2      61cdffb25ceee7f47177eac5
# 3      61cdffb35ceee7f47177edd0
# 4      61cdffb35ceee7f47177ee40
# ...                         ...
# 68197  62a70203bd91c4f886aed414
# 68198  62a70204bd91c4f886aed4ad
# 68199  62a70204bd91c4f886aed545
# 68200  62a70204bd91c4f886aed605
# 68201  62a70204bd91c4f886aed7e1
#
#                                                      url  \
# 0      https://www.ah.nl/producten/product/wi484845/b...
# 1      https://www.ah.nl/producten/product/wi470071/p...
# 2      https://www.ah.nl/producten/product/wi506139/b...
# 3      https://www.ah.nl/producten/product/wi466547/b...
# 4      https://www.ah.nl/producten/product/wi469635/p...
# ...                                                  ...
# 68197  https://www.ah.nl/producten/product/wi411047/b...
# 68198  https://www.ah.nl/producten/product/wi407647/g...
# ...

# %%
ah
# Out:
#                             _id  \
# 0      61cdffb25ceee7f47177e9f1
# 1      61cdffb25ceee7f47177eb63
# 2      61cdffb25ceee7f47177eac5
# 3      61cdffb35ceee7f47177edd0
# 4      61cdffb35ceee7f47177ee40
# ...                         ...
# 68197  62a70203bd91c4f886aed414
# 68198  62a70204bd91c4f886aed4ad
# 68199  62a70204bd91c4f886aed545
# 68200  62a70204bd91c4f886aed605
# 68201  62a70204bd91c4f886aed7e1
#
#                                                      url  \
# 0      https://www.ah.nl/producten/product/wi484845/b...
# 1      https://www.ah.nl/producten/product/wi470071/p...
# 2      https://www.ah.nl/producten/product/wi506139/b...
# 3      https://www.ah.nl/producten/product/wi466547/b...
# 4      https://www.ah.nl/producten/product/wi469635/p...
# ...                                                  ...
# 68197  https://www.ah.nl/producten/product/wi411047/b...
# 68198  https://www.ah.nl/producten/product/wi407647/g...
# ...
