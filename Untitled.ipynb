# %%
import pymongo
import pandas as pd
MONGO_URI = 'mongodb+srv://sem:deka@cluster0.olmaj.mongodb.net/product_data?retryWrites=true&w=majority'
MONGO_DATABASE = 'product_data'

# %%
client = pymongo.MongoClient(MONGO_URI)
db = client[MONGO_DATABASE]
col = db['products']
doc = col.find({})

df =  pd.DataFrame(list(doc))
ah = df[df['url'].str.match(r'.*ah\.nl') == True]
deka = df[df['url'].str.match(r'.*dekamarkt\.nl') == True]
vomar = df[df['url'].str.match(r'.*vomar\.nl') == True]
jumbo = df[df['url'].str.match(r'.*jumbo\.com') == True]
compression_opts = dict(method='zip', archive_name='supermarkt.csv')  
df.to_csv('supermarkt.zip', index=False, compression=compression_opts)

# %%
for x in ah.iloc[:1].values:
    for y, z in zip(x, ah.iloc[:1]):
        print(z,':',y)
# list(ah['kenmerken'])
# Out:
# _id : 612b4d4cfcb5ea407c2dd6ca
# url : https://www.ah.nl/producten/product/wi398448/the-pie-factory-hartige-taart-runderstoof-ui
# naam : The Pie Factory Hartige taart runderstoof-ui
# omschrijving : ['Hartige Taart Pie Runderstoof met Ui']
# inhoud : ['250 Gram']
# kenmerken : []
# prijs : 2.99
# aanbieding : False
# categorie : nan

# %%
for x in deka.iloc[:1].values:
    for y, z in zip(x, ah.iloc[:1]):
        print(z,':',y)
# list(deka.omschrijving.unique())
# Out:
# _id : 612b4e04fcb5ea407c2e8e65
# url : https://www.dekamarkt.nl/boodschappen/aardappelen-groente-fruit/sla-verse-kruiden/1-de-beste-rucola-125-g/43400
# naam : 1 de Beste Rucola
# omschrijving : Rucola
# inhoud : 125 g
# kenmerken : nan
# prijs : 1.69
# aanbieding : []
# categorie : ['Aardappelen groente fruit', 'Sla verse kruiden']

# %%
len(ah['naam'].unique())
# Out:
# 4802

# %%
len(ah['naam'])
# Out:
# 5093

# %%
ah[ah['url'] == 'https://www.ah.nl/producten/product/wi455430/ah-nederlandse-trostomaten']
# Out:
# Empty DataFrame
# Columns: [_id, url, naam, omschrijving, inhoud, kenmerken, prijs, aanbieding, categorie]
# Index: []

# %%
deka
# Out:
#                             _id  \
# 10     612b4e04fcb5ea407c2e8e65
# 11     612b4e05fcb5ea407c2e8f9c
# 12     612b4e06fcb5ea407c2e907a
# 13     612b4e08fcb5ea407c2e91a1
# 14     612b4e09fcb5ea407c2e936e
# ...                         ...
# 30676  612dffa8fcb5ea407c83c955
# 30677  612dffbdfcb5ea407c83e327
# 30678  612dffc7fcb5ea407c83ee23
# 30679  612dffcdfcb5ea407c83f57f
# 30680  612dffd3fcb5ea407c83fc0b
#
#                                                      url  \
# 10     https://www.dekamarkt.nl/boodschappen/aardappe...
# 11     https://www.dekamarkt.nl/boodschappen/aardappe...
# 12     https://www.dekamarkt.nl/boodschappen/aardappe...
# 13     https://www.dekamarkt.nl/boodschappen/aardappe...
# 14     https://www.dekamarkt.nl/boodschappen/aardappe...
# ...                                                  ...
# 30676  https://www.dekamarkt.nl/boodschappen/aardappe...
# 30677  https://www.dekamarkt.nl/boodschappen/kind-dro...
# 30678  https://www.dekamarkt.nl/boodschappen/maaltijd...
# 30679  https://www.dekamarkt.nl/boodschappen/aardappe...
# 30680  https://www.dekamarkt.nl/boodschappen/voorraad...
#
#                                               naam  \
# 10                              1 de Beste Rucola
# 11                             1 de Beste Oregano
# 12                                      Gember los
# 13            1 de Beste Jonge bladsla met rucola
# 14                           1 de Beste Basilicum
# ...                                            ...
# 30676                               Duo gele uien
# 30677  Loving Blends Shampoo argan en camelia olie
# 30678                    Daily Chef Mihoen goreng
# 30679                       Arlo Asperges geschild
# 30680                            Silvo Kipkruiden
#
#                                             omschrijving   inhoud kenmerken  \
# 10                                                Rucola    125 g       NaN
# 11                                               Oregano     20 g       NaN
# 12                                                           1 kg       NaN
# 13          Jonge bladsla in verschillende verhoudingen.     80 g       NaN
# 14                                             Basilicum     20 g       NaN
# ...                                                  ...      ...       ...
# 30676                                          Gele Uien  2 stuks       NaN
# 30677                                                      300 ml       NaN
# 30678  Gebakken rijstvermicelli met ham, varkensvlees...    900 g       NaN
# 30679                            Slierasperges, geschild    560 g       NaN
# 30680                                       Mix voor kip    135 g       NaN
#
#       prijs aanbieding                                       categorie
# 10     1.69         []  [Aardappelen groente fruit, Sla verse kruiden]
# 11     1.19         []  [Aardappelen groente fruit, Sla verse kruiden]
# 12     5.98         []  [Aardappelen groente fruit, Sla verse kruiden]
# 13     1.49         []  [Aardappelen groente fruit, Sla verse kruiden]
# 14     1.19         []  [Aardappelen groente fruit, Sla verse kruiden]
# ...     ...        ...                                             ...
# 30676  0.79         []            [Aardappelen groente fruit, Groente]
# 30677  4.19         []              [Kind drogisterij, Haarverzorging]
# 30678  4.99         []    [Maaltijden salades tapas, Verse maaltijden]
# 30679  3.39         []   [Aardappelen groente fruit, Groenteconserven]
# 30680  3.02         []              [Voorraadkast, Kruiden specerijen]
#
# [11223 rows x 9 columns]

# %%
ah.loc[ah['aanbieding'].isin([False, True]) == False]
# Out:
#                             _id  \
# 97     612b552dfcb5ea407c360369
# 98     612b552dfcb5ea407c360389
# 99     612b552ffcb5ea407c360497
# 100    612b5533fcb5ea407c360833
# 101    612b5533fcb5ea407c360898
# ...                         ...
# 29716  612dce8afcb5ea407c46ea29
# 29717  612dce8dfcb5ea407c46eca1
# 29718  612dce8dfcb5ea407c46ece7
# 29719  612dce8efcb5ea407c46ee0b
# 29720  612dce8ffcb5ea407c46ef43
#
#                                                      url  \
# 97     https://www.ah.nl/producten/product/wi129923/c...
# 98     https://www.ah.nl/producten/product/wi365953/m...
# 99     https://www.ah.nl/producten/product/wi214015/t...
# 100    https://www.ah.nl/producten/product/wi444111/c...
# 101    https://www.ah.nl/producten/product/wi166917/a...
# ...                                                  ...
# 29716  https://www.ah.nl/producten/product/wi486013/b...
# 29717  https://www.ah.nl/producten/product/wi485678/r...
# 29718  https://www.ah.nl/producten/product/wi496587/2...
# 29719  https://www.ah.nl/producten/product/wi413977/v...
# 29720  https://www.ah.nl/producten/product/wi385249/b...
#
#                                                     naam  \
# 97              Château l'Argenteyre Médoc Cru Bourgeois
# 98                                   Mooi Kaap Droë Rooi
# 99                  Terre di Verona Valpolicella Ripasso
# 100                      Cecchi Chianti Classico Riserva
# 101                                 AH Biologisch Merlot
# ...                                                  ...
# 29716  Bordeauxkist Chateau Barrail & Chateau Grand Puch
# 29717            Riporta Primitivo & Sangiovese Giftpack
# 29718                                        2Wine White
# 29719              Vacu Vin Waiters corkscrew kelnersmes
# 29720           Barrels and drums Chardonnay Alcoholvrij
#
#                                             omschrijving            inhoud  \
# 97                          [Chateau l'argenteyre medoc]  [750 Milliliter]
# 98                                                    []  [750 Milliliter]
# 99                                                [Wine]      [0.75 Liter]
# 100                                               [Wine]      [0.75 Liter]
# 101    [Merlot* \n*Van biologische oorsprong., FSC-Lo...  [750 Milliliter]
# ...                                                  ...               ...
# 29716                                             [Wine]      [0.75 Liter]
# 29717                                             [Wine]      [0.75 Liter]
# 29718                                             [Wine]      [0.25 Liter]
# 29719                                                 []         [88 Gram]
# 29720                                             [Wine]      [0.75 Liter]
#
#                                   kenmerken       prijs      aanbieding  \
# 97               [NIX18, Zwangerschapslogo]        9.99              []
# 98                      [Zwangerschapslogo]        2.99              []
# 99                      [Zwangerschapslogo]  63.9048.00         [ACTIE]
# 100                     [Zwangerschapslogo]       19.99              []
# 101    [Biologisch, FSC, Zwangerschapslogo]        4.29              []
# ...                                     ...         ...             ...
# 29716                   [Zwangerschapslogo]       19.99              []
# 29717                   [Zwangerschapslogo]       14.49              []
# 29718                   [Zwangerschapslogo]        2.49              []
# 29719                                    []        5.99              []
# 29720                                    []        5.99  [1 + 1 gratis]
#
#                                                categorie
# 97     [Wijn en bubbels, Rode wijn, Cabernet Sauvigno...
# 98     [Wijn en bubbels, Rode wijn, Overige rode wijn...
# 99     [Wijn en bubbels, Rode wijn, Rode wijn per doo...
# 100    [Wijn en bubbels, Rode wijn, Sangiovese, Sangi...
# 101    [Wijn en bubbels, Rode wijn, Merlot, Merlot (F...
# ...                                                  ...
# 29716                    [Wijn en bubbels, Wijngeschenk]
# 29717                    [Wijn en bubbels, Wijngeschenk]
# 29718  [Wijn en bubbels, Witte wijn, Witte wijn (klein)]
# 29719  [Wijn en bubbels, Wijnaccessoires, Kurkentrekker]
# 29720  [Wijn en bubbels, Witte wijn, Alcoholvrije wit...
#
# [1785 rows x 9 columns]

# %%
vomar
# Out:
#                             _id  \
# 12292  612bc54cfcb5ea407cb86d56
# 12293  612bc54dfcb5ea407cb86dcc
# 12294  612bc54efcb5ea407cb86f34
# 12295  612bc54ffcb5ea407cb8706e
# 12296  612bc551fcb5ea407cb87147
# ...                         ...
# 24780  612cb09afcb5ea407cde9661
# 25581  612cb4aafcb5ea407ce7c37a
# 26477  612cb93bfcb5ea407cf7425c
# 26479  612cb93dfcb5ea407cf74760
# 30068  612de002fcb5ea407c5abb0a
#
#                                                      url  \
# 12292  https://www.vomar.nl/producten/baby-kind/baby-...
# 12293  https://www.vomar.nl/producten/voorraadkast/zo...
# 12294  https://www.vomar.nl/producten/voorraadkast/tu...
# 12295  https://www.vomar.nl/producten/voorraadkast/so...
# 12296  https://www.vomar.nl/producten/voorraadkast/pa...
# ...                                                  ...
# 24780  https://www.vomar.nl/producten/vers/vlees/been...
# 25581  https://www.vomar.nl/producten/vers/fruit/bio-...
# 26477  https://www.vomar.nl/producten/voorraadkast/bi...
# 26479  https://www.vomar.nl/producten/voorraadkast/bi...
# 30068  https://www.vomar.nl/producten/vers/vlees/csw-...
#
#                                                     naam  \
# 12292  Sore Junior Mais Fingers Appel Kaneel 12+ Maan...
# 12293                 Van Gilse Fijne Kaneelsuiker 200 g
# 12294                      Bio+ Notenreep Kokos 3 x 35 g
# 12295              Hak Rode Kool met Stukjes Appel 180 g
# 12296                  Thai Temple Noodles Cup Beef 60 g
# ...                                                  ...
# 24780             Vomar Beenham Honing-Mosterd ca. 770 g
# 25581                           Bio+ Biologische Bananen
# 26477         Weight Care Mijn Moment Melkchocolade 20 g
# 26479  Weight Care Tussendoortje Krokante Reep Pure C...
# 30068            Vomar Boerenschnitzel 2 Stuks ca. 320 g
#
#                                             omschrijving  \
# 12292                   Junior Maisfingers Appel Kaneel.
# 12293                                 Fijne kaneelsuiker
# 12294           Biologische notenreep met dadel en kokos
# 12295                        Rode kool MET STUKJES APPEL
# 12296                          Instant noedels rundsmaak
# ...                                                  ...
# 24780  Varkensvleesproduct met honing-mosterdtopping ...
# 25581                                Biologische bananen
# 26477                      Granenreep met melkchocolade.
# 26479  Krokante reep omhuld met een fijn laagje pure ...
# 30068            Geportioneerd en gepaneerd varkensvlees
#
#                                                   inhoud kenmerken  prijs  \
# 12292                   Junior Maisfingers Appel Kaneel.       NaN   1.79
# 12293                                 Fijne kaneelsuiker       NaN   0.99
# 12294           Biologische notenreep met dadel en kokos       NaN   2.49
# 12295                        Rode kool MET STUKJES APPEL       NaN   0.99
# 12296                          Instant noedels rundsmaak       NaN   0.69
# ...                                                  ...       ...    ...
# 24780  Varkensvleesproduct met honing-mosterdtopping ...       NaN   8.45
# 25581                                Biologische bananen       NaN   1.69
# 26477                      Granenreep met melkchocolade.       NaN   0.89
# 26479  Krokante reep omhuld met een fijn laagje pure ...       NaN   2.35
# 30068            Geportioneerd en gepaneerd varkensvlees       NaN  15.98
#
#       aanbieding                                          categorie
# 12292        NaN              [Baby & Kind, Baby- en Kindervoeding]
# 12293        NaN                        [Voorraadkast, Zoetstoffen]
# 12294        NaN                     [Voorraadkast, Tussendoortjes]
# 12295        NaN  [Voorraadkast, Soepen, conserven, sauzen & sma...
# 12296        NaN         [Voorraadkast, Pasta, rijst & wereldmarkt]
# ...          ...                                                ...
# 24780        NaN                                      [Vers, Vlees]
# 25581        NaN                                      [Vers, Fruit]
# 26477        NaN                [Voorraadkast, Biologisch & Reform]
# 26479        NaN                [Voorraadkast, Biologisch & Reform]
# 30068        NaN                                      [Vers, Vlees]
#
# [6994 rows x 9 columns]

# %%
jumbo
# Out:
#                             _id  \
# 19261  612c93c2fcb5ea407cad0db5
# 19262  612c93c4fcb5ea407cad1067
# 19263  612c93c5fcb5ea407cad111c
# 19264  612c93c6fcb5ea407cad1339
# 19265  612c93c7fcb5ea407cad1465
# ...                         ...
# 28329  612cf9f9fcb5ea407c6a204d
# 28337  612cfa39fcb5ea407c6a6ee1
# 28340  612cfa4efcb5ea407c6a882e
# 28345  612cfa62fcb5ea407c6a9fb0
# 28347  612cfa76fcb5ea407c6ab861
#
#                                                      url  \
# 19261  https://www.jumbo.com//producten/jumbo-komkomm...
# 19262  https://www.jumbo.com//producten/jumbo-runderg...
# 19263  https://www.jumbo.com//producten/tomaten-500g-...
# 19264  https://www.jumbo.com//producten/jumbo-paprika...
# 19265  https://www.jumbo.com//producten/jumbo-paprika...
# ...                                                  ...
# 28329  https://www.jumbo.com//producten/unox-knaks-pa...
# 28337  https://www.jumbo.com//producten/jumbo-kruiden...
# 28340  https://www.jumbo.com//producten/unox-good-noo...
# 28345  https://www.jumbo.com//producten/anta-flu-clas...
# 28347  https://www.jumbo.com//producten/kuhne-schlemm...
#
#                                                     naam omschrijving  inhoud  \
# 19261                                    Jumbo Komkommer          NaN    None
# 19262                            Jumbo Rundergehakt 500g          NaN   500 g
# 19263                                       Tomaten 500g          NaN   500 g
# 19264                         Jumbo Paprika en Courgette          NaN   250 g
# 19265                                 Jumbo Paprika Rood          NaN    None
# ...                                                  ...          ...     ...
# 28329                              Unox Knaks Party 400g          NaN   400 g
# 28337                       Jumbo Kruidenmix Nasi 23, 2g          NaN  23,2 g
# 28340                      Unox Good Noodles Cup Kip 65g          NaN    65 g
# 28345                 ANTA flu Classic keelpastille 275g          NaN   275 g
# 28347  Kühne Schlemmertöpfchen Kleine Augurken met Fi...          NaN   530 g
#
#       kenmerken prijs                         aanbieding  \
# 19261       NaN  0.55                                 []
# 19262       NaN  3.69                                 []
# 19263       NaN  0.99                                 []
# 19264       NaN  1.44                                 []
# 19265       NaN  0.89                                 []
# ...         ...   ...                                ...
# 28329       NaN  2.33  [Alleen online, 3 voor 5,00 euro]
# 28337       NaN  0.35                                 []
# 28340       NaN  1.28                                 []
# 28345       NaN  1.73                                 []
# 28347       NaN  2.23                                 []
#
#                                                categorie
# 19261  [Groente, Tomaten, paprika, komkommer, Komkomm...
# 19262  [Vlees, vis, vegetarisch, Gehakt, worst, burge...
# 19263  [Groente, Tomaten, paprika, komkommer, Tomaten...
# 19264    [Groente, Tomaten, paprika, komkommer, Paprika]
# 19265    [Groente, Tomaten, paprika, komkommer, Paprika]
# ...                                                  ...
# 28329  [Koek, gebak, snoep, chips, Tapas, borrelhapje...
# 28337  [Koken, soepen, maaltijden, Oosterse keuken, O...
# 28340  [Koken, soepen, maaltijden, Verse kant en klar...
# 28345          [Koek, gebak, snoep, chips, Keelsnoepjes]
# 28347  [Koken, soepen, maaltijden, Sauzen, dressing, ...
#
# [7371 rows x 9 columns]
